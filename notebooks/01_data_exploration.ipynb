# %%
import pandas as pd

df = pd.read_csv("/data/raw/PS_2026.01.19_01.24.31.csv")
df.head()

# %%
df.shape
df.columns

# %%
(df.isna().mean().sort_values(ascending=False) * 100).head(20)

# %%
df.describe(include="number").T
