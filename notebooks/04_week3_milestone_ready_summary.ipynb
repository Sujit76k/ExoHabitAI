# %%
summary = f"""
✅ WEEK 3 SUMMARY (Milestone Ready)

1) Dataset Used:
- Feature engineered dataset: feature_engineered_exoplanets.csv

2) Target Variable:
- habitability (0 = Not Habitable, 1 = Habitable)

3) Features:
- Top correlated numeric features + categorical features
- Preprocessing handled using pipeline (imputer + scaler + encoding)

4) Train-Test Split:
- 80:20 split (train_test_split)

5) Model:
- RandomForestClassifier baseline
- class_weight='balanced'

6) Evaluation:
- Accuracy: {acc}
- Confusion Matrix:
{cm}
"""
print(summary)
